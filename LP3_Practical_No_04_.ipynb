# %% [markdown]
# <a href="https://colab.research.google.com/github/Adiii99/Best_travelo_app/blob/main/LP3_Practical_No_04_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 2
lr = 0.01  # learning rate
precision = 0.000001
previous_step_size = 1
max_iter = 10000
iters = 1
gf = lambda x : (x+3) ** 2  # gradient function

# %%
import matplotlib.pyplot as plt
gd = []

# %%
while precision < previous_step_size and iters < max_iter:
  prev = x
  x = x -lr * gf(prev)
  previous_step_size = abs(x - prev)
  iters += 1
  print('Iteration :',iters,'Value:',x)
  gd.append(x)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration : 4977 Value: -2.9800061882927977
# Iteration : 4978 Value: -2.9800101858178634
# Iteration : 4979 Value: -2.9800141817445738
# Iteration : 4980 Value: -2.9800181760738873
# Iteration : 4981 Value: -2.9800221688067614
# Iteration : 4982 Value: -2.980026159944153
# Iteration : 4983 Value: -2.980030149487019
# Iteration : 4984 Value: -2.980034137436314
# Iteration : 4985 Value: -2.980038123792993
# Iteration : 4986 Value: -2.98004210855801
# Iteration : 4987 Value: -2.9800460917323184
# Iteration : 4988 Value: -2.9800500733168698
# Iteration : 4989 Value: -2.9800540533126165
# Iteration : 4990 Value: -2.980058031720509
# Iteration : 4991 Value: -2.9800620085414975
# Iteration : 4992 Value: -2.9800659837765315
# Iteration : 4993 Value: -2.9800699574265597
# Iteration : 4994 Value: -2.9800739294925296
# Iteration : 4995 Value: -2.980077899975388
# Iteration : 4996 Value: -2.980081868876082
# ...

# %%
print('Local Maxima:', x)
# Out:
# Local Maxima: -2.990001240409911

# %%
plt.plot(range(9975),gd)
